# %% [markdown]
# <a href="https://colab.research.google.com/github/shamshudzoha2002-prog/python--assignments/blob/main/Logical_operator_class_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Problem 1: Check sign
#
# **Question:** Write a program that checks if a number is positive, negative, or zero.
#
# **Approach:** Think about comparing the number with 0 using if, elif, and else.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Enter your answer here
number=int(input("Enter number :"))
if number >0:
   print("positive")
elif number <0:
   print("Negative")
else:
   print("Zero")
# Out:
# Enter number :4
# positive

# %% [markdown]
# ++++++## Problem 2: Leap Year
#
# **Question:** Check if a given year is a leap year.
#
# **Approach:** Apply the rules: divisible by 4, but centuries must be divisible by 400.
#
# Rules: Year divisible by 4 is leap, but if divisible by 100 it must also be divisible by 400.

# %%
# Enter your answer here
year =int(input("Enter year :"))
if year%4==0 and year%100!=0 or year%400==0:
  print("Leap year")
else:
  print("Not a leap year")
# Out:
# Enter year :2017
# Not a leap year

# %% [markdown]
# ## Problem 3: Grade Bands
#
# **Question:** Print grade category based on marks: Excellent, Good, Average, Fail.
#
# **Approach:** Build multiple conditions using elif to check ranges.
#
# Take marks (0-100) and print:
# - 90–100 → Excellent
# - 75–89 → Good
# - 50–74 → Average
# - else → Fail

# %%
# Enter your answer here

marks=int(input("Enter marks"))

if marks>=90 and marks<=100:
    print("Excellent")
elif marks >=75 and marks<89:
    print("Good")
elif marks >=50 and marks<74:
    print("Average")
else:
    print("Fail")
# Out:
# Enter marks99
# Excellent

# %% [markdown]
# ## Problem 4: Validate Login
#
# **Question:** Check username=='admin' and password=='1234'.
#
# **Approach:** Use logical AND to validate both conditions.
#
#
# Input: username & password.
#
# If username == 'admin' and password == '1234'
# print 'Login successful',
# else 'Invalid credentials'.

# %%
# Enter your answer here
username =input("Enter username : ")
password =input("Enter password : ")

if username == "admin" and password == "1234" :
   print("Login successful")
else:
   print("Invalid credentials")
# Out:
# Enter username : admin
# Enter password : 1234
# Login successful

# %% [markdown]
# ## Problem 5: Movie Ticket Discount
#
# **Question:** Apply discount based on age.
#
# **Approach:** Use ordered elif statements from smallest to largest age group.
#
# Apply discounts based on age:
# - Age < 12 → 50% discount
# - Age between 12 and 18 → 30% discount
# - Age between 18 and 60 → no discount
# - Age > 60 → 40% discount

# %%
# Enter your answer here
age =int(input("Enter age : "))
if age<12:
   print("50 percent_discount")
elif age >=12 and age<=18:
   print("30 percent_discount")
elif age >=18 and age <=60:
   print("No discount")
else:
   print("40 percent_discount")
# Out:
# Enter age : 45
# No discount

# %% [markdown]
# ## Problem 6: Placement Eligibility
#
# **Question:** Check CGPA, backlog status, and project count.
#
# **Approach:** All conditions must be true → use AND operator.
#
#
# Conditions:
# - CGPA ≥ 7
# - No backlog (enter 'yes' or 'no')
# - Completed >= 2 major projects
# Print whether the student is eligible.

# %%
# Enter your answer here
cgpa = float(input("Enter your cgpa : "))
backlog_status = input("Enter {YES or No} : ")
project_count = int(input("Enter number of project completed : "))

if cgpa >= 7 and backlog_status == "No"  and project_count >= 2 :
   print("you are eligible for placement")
else:
   print("you are not eligible for placement")
# Out:
# Enter your cgpa : 7.5
# Enter {YES or No} : No
# Enter number of project completed : 4
# you are eligible for placement

# %% [markdown]
# ## Problem 7: Delivery Charge System
#
# **Question:** Calculate final delivery charge based on prime membership, amount, and distance.
#
# **Approach:** Start with prime-check, then inside it apply nested if blocks.
#
# Inputs:
# - order_amount (int)
# - is_prime_member (yes/no)
# - distance_km (float)
#
# Rules:
# - If prime member → Free delivery
# - Else:
#   - If amount ≥ 500:
#     - If distance ≤ 5 km → Free
#     - Else → ₹20 extra
#   - Else:
#     - If distance ≤ 5 km → ₹30
#     - Else → ₹50

# %%
# Enter your answer here
order_amount=int(input("Enter order_amount : "))
is_prime_member=input("Enter is_prime_member [YES OR NO] : ")
distance_km=float(input("Enter distance : "))

if is_prime_member =="Yes" :
   print("Free delivery")
else:
   if order_amount>=500:
      if distance_km<=5:
         print("Free")
      else:
         print("give extra 20 rupees")
   else:
        if distance <=5:
           print("rupees 30")
        else:
            print("rupees 50")
# Out:
# Enter order_amount : 550
# Enter is_prime_member [YES OR NO] : yes
# Enter distance : 5
# Free

# %% [markdown]
# ## Problem 8: ATM Withdrawal Simulation
#
# **Question:** Simulate ATM rules: multiples of 100, sufficient balance, manager approval.
#
# **Approach:** Check errors first, then nested conditions for amount > 10000.
#
# Inputs:
# - balance
# - amount
#
# Logic:
# - If amount % 100 != 0 → reject (ATM works with ₹100 multiples)
# - If amount > balance → reject
# - Else:
#   - if amount > 10000 → ask for manager approval
#   - else → withdraw success

# %%
# Enter your answer here
balance=int(input("Enter balance :"))
amount=int(input("Enter amount :"))

if amount % 100 != 0:
   print("Reject{ATM works with 100 multiple}")
if amount > balance:
   print("Reject")
else:
   if amount >10000:
      print("Ask for manager approvel")
   else:
      print("Withdrawn success")
# Out:
# Enter balance :8000
# Enter amount :10000
# Reject

# %% [markdown]
# ## Problem 9: Employee Performance Rating
#
# **Question:** Assign performance rating based on sales, feedback, attendance.
#
# **Approach:** Prioritize attendance rule, then apply nested conditions.
#
# Inputs:
# - sales (₹)
# - feedback (0-5 scale)
# - attendance (%)
#
# Logic:
# - If attendance < 70 → 'Poor'
# - Else:
#   - If sales > 100000 AND feedback > 4.5 → 'Excellent'
#   - If sales > 70000 OR feedback > 4 → 'Good'
#   - Else → 'Average'

# %%
# Enter your answer here
sales =int(input("Enter sales :"))
feedback =float(input("Enter feedback :"))
attendence =int(input("Enter percentage :"))

if attendence<70:
   print("poor")
else:
    if sales >100000 and feedback >4.5:
       print("Excellent")
    if sales >70000 or feedback >4:
       print("Good")
    else:
       print("Average")
# Out:
# Enter sales :150000
# Enter feedback :5
# Enter percentage :70
# Excellent
# Good

# %% [markdown]
# ## Problem 10: Credit Card Eligibility
#
# **Question:** Determine card eligibility based on age, salary, credit score.
#
# **Approach:** First filter by age, then use nested if blocks for salary and credit score.
#
# Inputs:
# - salary
# - credit_score
# - age
#
# Logic:
# - If age < 21 → Not eligible
# - Else:
#   - If salary ≥ 40,000:
#     - If credit_score ≥ 750 → Gold Card
#     - Else → Silver Card
#   - Else:
#     - If credit_score ≥ 800 → Silver Card
#     - Else → Not eligible

# %%
# Enter your answer here
salary=int(input("Enter salary :"))
credit_score=int(input("Enter credit_score :"))
age=int(input("Enter age :"))

if age<21:
   print("Not eligible")
else:
   if salary>=40000:
      if credit_score>=750:
         print("Gold card")
      else:
         print("Silver card")
   else:
         if credit_score>=800:
             print("Silver card")
         else:
             print("Not eligible")
# Out:
# Enter salary :40000
# Enter credit_score :740
# Enter age :27
# Silver card
